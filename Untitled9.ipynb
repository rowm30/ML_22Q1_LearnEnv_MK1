# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('up_res.csv')

# %%
plt.figure(figsize=(20,20),dpi=600)
sns.scatterplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data=df,x='seat_allotment')
# Out:
# <AxesSubplot:xlabel='seat_allotment', ylabel='count'>

# %%
df.max()
# Out:
# seat_allotment               SP
# phase                         7
# ac_no                       403
# ac                      Zamania
# district               Varanasi
# candidate         ZURGHAM MEHDI
# party                    others
# votes                    262741
# dtype: object

# %%
df.nlargest(5,'votes')
# Out:
#      seat_allotment  phase  ac_no            ac             district  \
# 657             INC      1     55     Sahibabad            Ghaziabad
# 731              SP      1     61         Noida  Gautam Buddha Nagar
# 2841             FF      4    227  Mehroni (SC)             Lalitpur
# 2829             SP      4    226      Lalitpur             Lalitpur
# 2867            INC      4    229     Rath (SC)             Hamirpur
#
#                candidate party   votes
# 657   SUNIL KUMAR SHARMA  BJP+  262741
# 731         PANKAJ SINGH  BJP+  162417
# 2841         MANOHAR LAL  BJP+  159291
# 2829   RAMRATAN KUSHWAHA  BJP+  156942
# 2867     MANISHA ANURAGI  BJP+  147526
